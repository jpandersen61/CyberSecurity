# %% [markdown]
# <a href="https://colab.research.google.com/github/jpandersen61/CyberSecurity/blob/main/Python_Execise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 2: Python Basics

# %% [markdown]
# ## 2.1 Python Syntax

# %% [markdown]
# ### 2.1.1 Indentation

# %% [markdown]
# *Main points:*
#
#
# *   Code blocks, that is a sequence code lines performed in a row
# *   Code blocks are expressed with indentation
# *   Not with curly brackets `{...}` like in programmings languages such as C# and Java as shown below
# ```
# if x > 0:
# {
#     print("x is positive")
# }
# else:
# {
#     print("x is non-positive")
# }
# ```

# %% [markdown]
# *Read more here:*
# *   About [Python syntax](https://www.w3schools.com/python/python_syntax.asp)

# %% [markdown]
# *Code block:*

# %%
x = 5

if x > 0:
    print("x is positive")
else:
    print("x is non-positive")
# Out:
# x is non-positive

# %% [markdown]
# *Exercise(s):*

# %% [markdown]
# 1.   Perform the code cell above -> Click on arrow/triangle
# 2.   Try with different values of `x` and then perform the code cell - e.g. `x=10`, `x=0`, `x=-5` ....
#
#
# 1.   The try to explain the `if ... :`... `else:` to yourself
# 2.   Try to remove indentation -> what is happening?

# %% [markdown]
# ### 2.1.2 Comments

# %% [markdown]
# *Main points:*
#
#
# *   Lets you interleave text, that is not code, but rather for explanation
# *   Text following a `#` are left are during interpration by Python

# %% [markdown]
# *Code block:*

# %%
# This is a single-line comment

x = 5  # This is an inline comment

# You can also use comments to
# explain code over multiple lines

# %% [markdown]
# *Exercise(s):*
#
#
# 1.   Perform the code cell above
# 2.   Add a line `print(x)` in the bottom of code clock above and perform it again -> what is happening?

# %% [markdown]
# ### 2.1.3 Variables

# %% [markdown]
# *Code block:*

# %%
name = "Alice"
age = 30

# %% [markdown]
# *Exercise(s):*
#
#
# 1.   Perform the code cell above
# 2.   Create a new code with this Python line and `print(name,age)` and perform it

# %% [markdown]
# ### 2.1.4 Statements and Expressions

# %% [markdown]
# *Code block:*

# %%
x = 5  # assignment statement
print(x)  # function call statement
# Out:
# The value of x is:
# 5

# %% [markdown]
# *Exercise(s):*
#
#
# 1.   Add another code line `print("The value of x is:")` to the code cell above so it makes sense and perform it

# %% [markdown]
# ### 2.1.5 Basic Data Types and Operators

# %% [markdown]
# Read more here:
#
#
# *   About [Arithmetic operators](https://www.w3schools.com/python/python_operators_arithmetic.asp)
#
#
#
# *   About [Comparison operators](https://www.w3schools.com/python/python_operators_comparison.asp)
# *   About [Logical operators](https://www.w3schools.com/python/python_operators_logical.asp)

# %% [markdown]
# *Code block:*

# %%
# Arithmetic operations
x = 5 + 3  # addition
y = 7 - 2  # subtraction
z = 4 * 2  # multiplication
a = 9 / 3  # division

# Comparison operations
b = 5 > 3  # greater than
c = 4 < 2  # less than
d = 5 == 5  # equal to
e = 5 != 3  # not equal to

# Logical operations
f = True and False  # logical AND
g = True or False   # logical OR
h = not True        # logical NOT

# %% [markdown]
# ### Exercise 2.1.1: Calculate the Area of a Rectangle

# %% [markdown]
# *Code block:*

# %%
length = 10
width = 5
area = length * width
print("The area of the rectangle is", area)
# Out:
# The area of the rectangle is 50

# %% [markdown]
# *More exercise(s):*
#
# 1.   Perform the code block above -> Does it make sense?
# 2.   Copy the code block and change the code, it calculates the area of a  right triangle -> Test it!

# %% [markdown]
# ### Exercise 2.1.2: Printing a Triangle

# %% [markdown]
# *Code block:*

# %%
print("  *  ")
print(" *** ")
print("*****")
# Out:
#   *
#  ***
# *****

# %% [markdown]
# *Exercise(s):*
#
#
# 1.   Add another layer in the triangle
# 2.   What would be nice to have, if want some Python code that can print a triangle with any number of layers?

# %% [markdown]
# ### Exercise 2.1.3: Printing a Multiplication Table

# %% [markdown]
# *Read more here:*
#
#
# *   About [F-strings formatting](https://www.w3schools.com/python/python_string_formatting.asp)

# %% [markdown]
# *Code block:*

# %%
number = 7

print(f"{number} x 1 = {number * 1}")
print(f"{number} x 2 = {number * 2}")
print(f"{number} x 3 = {number * 3}")
print(f"{number} x 4 = {number * 4}")
print(f"{number} x 5 = {number * 5}")
print(f"{number} x 6 = {number * 6}")
print(f"{number} x 7 = {number * 7}")
print(f"{number} x 8 = {number * 8}")
print(f"{number} x 9 = {number * 9}")
print(f"{number} x 10 = {number * 10}")
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %% [markdown]
# *More exercise(s):*
#
# 1.   Explain the F-string formatting above to your self

# %% [markdown]
# ## 2.2 Variables and Data Types

# %% [markdown]
# ### 2.2.1 Variables

# %% [markdown]
# *Code block:*

# %%
name = "John"
age = 25
_height = 175.5

# %% [markdown]
# *Exercise(s):*
#
#
# 1.   Print the values of the variables in the code cell above nicely with F-strings formatting

# %% [markdown]
# *Code block:*

# %%
x, y, z = 1, 2, 3

# %% [markdown]
# *Exercise(s):*
#
# 1.   Do more printing with F-strings formatting

# %% [markdown]
# ### 2.2.2 Data Types

# %% [markdown]
# *Read more here:*
#
#
# *   About [Python data tyoes](https://www.w3schools.com/python/python_datatypes.asp)

# %% [markdown]
# *Code block:*

# %%
x = 42
print(type(x))  # Output: <class 'int'>

y = 3.14
print(type(y))  # Output: <class 'float'>

z = "Python"
print(type(z))  # Output: <class 'str'>

a = True
print(type(a))  # Output: <class 'bool'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# *Exercise(s):*
#
# 1.   Try simple and quick test of the type of a variable with just performing `type(...)` in a code cell

# %% [markdown]
# ### 2.2.3 Type Conversion

# %% [markdown]
# *Code block:*

# %%
x = 5.5
y = int(x)  # Convert float to int, y becomes 5

a = 3
b = float(a)  # Convert int to float, b becomes 3.0

c = 42
d = str(c)  # Convert int to str, d becomes "42"

e = "123"
f = int(e)  # Convert str to int, f becomes 123

# %% [markdown]
# *Exercise(s):*
# 1.   Test each variable in the code block above with the `type(...)` function

# %% [markdown]
# ### Exercise 2.2.1: Celsius to Fahrenheit Converter

# %% [markdown]
# *Code block:*

# %%
celsius = 30
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius}°C is equal to {fahrenheit}°F")
# Out:
# 30°C is equal to 86.0°F

# %% [markdown]
# *More exercise(s):*

# %% [markdown]
# *More exercise(s):*
#
#
# 1.   Convert to [Reaumur](https://da.wikipedia.org/wiki/Reaumur) temperature instead of fahreheit

# %% [markdown]
# ### Exercise 2.2.2: Calculate the Area and Perimeter of a Rectangle

# %% [markdown]
# *Code block:*

# %%
length = 5
width = 3

area = length * width
perimeter = 2 * (length + width)

print(f"The area of a rectangle with length {length} and width {width} is {area}")
print(f"The perimeter of a rectangle with length {length} and width {width} is {perimeter}")

# %% [markdown]
# *More exercise(s):*
# 1.   Calculate the perimeter of a right triangle?

# %% [markdown]
# ### Exercise 2.2.3: Simple Interest Calculator

# %% [markdown]
# *Code block:*

# %%
principal = 1000
rate = 0.05
time = 3

simple_interest = principal * rate * time

print(f"The simple interest earned on an investment of ${principal} at a rate of {rate * 100}% over {time} years is ${simple_interest}")
# Out:
# The simple interest earned on an investment of $1000 at a rate of 5.0% over 3 years is $150.0

# %% [markdown]
# ### 2.3 Operators

# %% [markdown]
# ### 2.3.1 Arithmetic Operators

# %% [markdown]
# *Code block:*

# %%
x = 5
y = 2

print(x + y)  # Output: 7
print(x - y)  # Output: 3
print(x * y)  # Output: 10
print(x / y)  # Output: 2.5
print(x // y) # Output: 2
print(x % y)  # Output: 1
print(x ** y) # Output: 25
# Out:
# 7
# 3
# 10
# 2.5
# 2
# 1
# 25

# %% [markdown]
# *Exercise(s):*
# 1.   Make a more nice formatting with F-strings

# %% [markdown]
# ### 2.3.2 Comparison Operators

# %% [markdown]
# *Code block:*

# %%
x = 5
y = 2

print(x == y)  # Output: False
print(x != y)  # Output: True
print(x > y)   # Output: True
print(x < y)   # Output: False
print(x >= y)  # Output: True
print(x <= y)  # Output: False
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# *Exercise(s):*
# 1.   Make a more nice formatting with F-strings

# %% [markdown]
# ### 2.3.3 Assignment Operators

# %% [markdown]
# *Code block:*

# %%
x = 5

x += 3  # Same as x = x + 3, x becomes 8
x -= 2  # Same as x = x - 2, x becomes 6
x *= 4  # Same as x = x * 4, x becomes 24
x /= 3  # Same as x = x / 3, x becomes 8.0
x //= 2 # Same as x = x // 2, x becomes 4.0
x %= 3  # Same as x = x % 3, x becomes 1.0
x **= 2 # Same as x = x ** 2, x becomes 1.0

# %% [markdown]
# Exercise(s):
# 1.   Try to explain the code cell above

# %% [markdown]
# ### 2.3.4 Logical Operator

# %% [markdown]
# *Code block:*

# %%
x = True
y = False

print(x and y)  # Output: False
print(x or y)   # Output: True
print(not x)    # Output: False
# Out:
# False
# True
# False

# %% [markdown]
# ### 2.3.5 Bitwise Operators

# %% [markdown]
# *Code block:*

# %%
x = 5  # Binary: 0101
y = 3  # Binary: 0011

print(x & y)   # Output: 1 (Binary: 0001)
print(x | y)   # Output: 7 (Binary: 0111)
print(x ^ y)   # Output: 6 (Binary: 0110)
print(~x)      # Output: -6 (Binary: 1010)
print(x << 2)  # Output: 20 (Binary: 10100)
print(x >> 1)  # Output: 2 (Binary: 0010)
# Out:
# 1
# 7
# 6
# -6
# 20
# 2

# %% [markdown]
# ### Exercise 2.3.1: Simple Arithmetic Operations

# %% [markdown]
# *Code block:*

# %%
num1 = 10
num2 = 5

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print(f"Sum: {sum}")
print(f"Difference: {difference}")
print(f"Product: {product}")
print(f"Quotient: {quotient}")
# Out:
# Sum: 15
# Difference: 5
# Product: 50
# Quotient: 2.0

# %% [markdown]
# ### Exercise 2.3.2: Maximum of Two Numbers

# %% [markdown]
# *Code block:*

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

max_num = num1 if num1 > num2 else num2

print(f"The maximum of {num1} and {num2} is {max_num}")
# Out:
# Enter the first number: 3
# Enter the second number: 2
# The maximum of 3.0 and 2.0 is 3.0

# %% [markdown]
# *More exercise(s):*
# 1.   Explain the code cell above
# 2.   What does the `input` function do for us?

# %% [markdown]
# ### Exercise 2.3.3: Calculate the Distance Between Two Points

# %% [markdown]
# *Code block:*

# %%
x1, y1 = 3, 4
x2, y2 = 6, 8

distance = ((x2 - x1) ** 2 + (y2 - y1) ** 2) ** 0.5

print(f"The distance between point A({x1}, {y1}) and point B({x2}, {y2}) is {distance:.2f}")
# Out:
# The distance between point A(3, 4) and point B(6, 8) is 5.00

# %% [markdown]
# *More exercise(s):*
# 1.   Explain the code cell above
