# %% [markdown]
# <a href="https://colab.research.google.com/github/jpandersen61/CyberSecurity/blob/main/Standard_Python_Execises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 7: Modules and Packages

# %% [markdown]
# ## 7.1: Importing Modules

# %%
import math

# %%
import math

square_root = math.sqrt(16)
print(square_root)  # Output: 4.0
# Out:
# 4.0

# %%
from math import sqrt

square_root = sqrt(16)
print(square_root)  # Output: 4.0
# Out:
# 4.0

# %%
import math as m

square_root = m.sqrt(16)
print(square_root)  # Output: 4.0
# Out:
# 4.0

# %% [markdown]
# ### Random Number Generator

# %%
import random

random_integer = random.randint(1, 100)
print(random_integer)
# Out:
# 6

# %% [markdown]
# ### Current Date and Time

# %%
import datetime

current_date_time = datetime.datetime.now()
print(current_date_time)
# Out:
# 2026-09-23 18:18:40.125070

# %% [markdown]
# ### Exercise: Date and time

# %% [markdown]
# 1.   Make a Python file that executes the `datetime` module example
# 2.   Do different formattings with strftime `function` in the `datetime` module

# %% [markdown]
# ### Calculate the Area of a Circle

# %%
from math import pi

radius = 5
area = pi * radius * radius
print(area)
# Out:
# 78.53981633974483

# %% [markdown]
# ## 7.2: Standard Library Modules

# %% [markdown]
# ### 7.2.1: os

# %%
import os
# Get the current working directory
current_directory = os.getcwd()
print(current_directory)
# Out:
# /content

# %% [markdown]
# ### Exercise: Get current working directory

# %% [markdown]
# 1.   Make a Python file that executes the os module example
# 2.   Find other functions in the [OS Module](https://docs.python.org/3/library/os.html) to try

# %% [markdown]
# ### 7.2.2: sys

# %%
import sys

# Print the Python version
print(sys.version)
# Out:
# 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]

# %% [markdown]
# ### 7.2.3: re

# %%
import re

text = "Hello, my name is John Doe"
pattern = r"\b\w{4}\b"

four_letter_words = re.findall(pattern, text)
print(four_letter_words)
# Out:
# ['name', 'John']

# %% [markdown]
# ### 7.2.4: json

# %%
import json

data = {
    "name": "John",
    "age": 30,
    "city": "New York"
}

# Convert the Python dictionary to a JSON string
json_data = json.dumps(data)
print(json_data)
# Out:
# {"name": "John", "age": 30, "city": "New York"}

# %%
type(data)
# Out:
# dict

# %%
type (json_data)
# Out:
# str

# %% [markdown]
# ### 7.2.5: urllib

# %%
import urllib.request

url = "https://www.example.com"
response = urllib.request.urlopen(url)
content = response.read()

print(content)
# Out:
# b'<!doctype html><html lang="en"><head><title>Example Domain</title><link rel="icon" href="data:,"><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style></head><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.</p><p><a href="https://iana.org/domains/example">Learn more</a></p></div></body></html>\n'

# %% [markdown]
# ### Exercise: Request web page

# %% [markdown]
# 1.   Make Python file that executes the urllib example
# 2.   The script should prompt the user for the web page URL to be fetched with the [input function](https:// [link text](https://docs.python.org/3/builtins/functions.html)) and print out the content

# %% [markdown]
# #Binary convertion

# %% [markdown]
# In this section you find 2 exercises about decimal <-> binary convertion.
#
#
# Find inspiration for doing the exercises in this reference: [Python Convert Decimal Number to Binary and Vice Versa](https://pynative.com/python-convert-decimal-number-to-binary-and-vice-versa/)

# %% [markdown]
# ### Exercise: Converting decimal (integer) to binary

# %% [markdown]
# Make a Python script that converts from decimal to binary - e.g. 20 -> 10100. The script should prompt the user for the number to be converted with the [input function](https://docs.python.org/3/builtins/functions.html) and print out the result.
#
# Hint: You can do the conversion with the [format function](http://docs.python.org/3/builtins/functions.html) like this `format(decimal, 'b')`

# %%
decimal = 20
binary = format(decimal, 'b')
print(f"Binary of {decimal} is {binary}")
# Out:
# Binary of 20 is 10100

# %%
print("Converting decimal to binary")
number  = int(input("Enter number: "))
binary = format(number, 'b')
print(f"Binary of {number} is {binary}")
# Out:
# Converting decimal to binary
# Enter number: 4
# Binary of 4 is 100

# %% [markdown]
# ### Exercise: Converting from binary to decimal

# %% [markdown]
# Make a Python script that converts from binary to decimal - e.g. 10100 -> 20. The script should prompt the user for the number to be converted with the [input function](https://docs.python.org/3/builtins/functions.html) and print out the result.
#
# Hint: You can do the convertion with the [int function](http://docs.python.org/3/builtins/functions.html) like this `int(binary, 2)`

# %%
binary = "1010"
decimal = int(binary, 2)
print(f"Decimal value of {binary} is {decimal}")
# Out:
# Decimal value of 1010 is 10
